# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# **My Jupyter Notebook on IBM Watson Studio**

# %% [markdown]
# **Wesley Capucho**
#
# Biomedical Engineering

# %% [markdown]
# *I am interested in data science because I want to work with scientific research in biomedical science and the data are a precious resource*

# %% [markdown]
# **The following code test a simple mathematical formula**

# %%
#area of a square formula = Side * Side (cm)

A = 26

print (A*A)
# Out:
# 676

# %% [markdown]
# <img src='![me.jpg](attachment:d1fdf72d-396f-4c6b-93ab-cfaaad66b98d.jpg)>

# %%
Avengers = ['Captain America', 'Iron man', 'Thor']
print (Avengers)
# Out:
# ['Captain America', 'Iron man', 'Thor']

# %% [markdown]
# (https://www.mit.edu/)
